# %% [markdown]
# # Basic array operations

# %% [markdown]
# You can add the arrays together with the plus sign.

# %%
import numpy as np

# %%
data = np.array([1, 2])
ones = np.ones(2, dtype=int)
data + ones
# Out:
# array([2, 3])

# %%
data - ones
# Out:
# array([0, 1])

# %%
data * data
# Out:
# array([1, 4])

# %%
data / data
# Out:
# array([1., 1.])

# %% [markdown]
# Basic operations are simple with NumPy. If you want to find the sum of the elements in an array, you’d use sum(). This works for 1D arrays, 2D arrays, and arrays in higher dimensions.

# %%
a = np.array([1, 2, 3, 4])

a.sum()
# Out:
# 10

# %% [markdown]
# To add the rows or the columns in a 2D array, you would specify the axis.

# %%
b = np.array([[1, 1], [2, 2]])

# %% [markdown]
# axis = 0 → rows go DOWN
#
# axis = 1 → columns go ACROSS

# %% [markdown]
# You can sum over the axis of rows with:

# %%
b.sum(axis=0)
# Out:
# array([3, 3])

# %%
# [1  1]   ↓
# [2  2]   ↓
# ---------
# [3  3]

# %% [markdown]
# You can sum over the axis of column with:

# %%
b.sum(axis=1)
# Out:
# array([2, 4])

# %%
# → [1 + 1] = 2
# → [2 + 2] = 4

# %% [markdown]
# ## The axis you specify is the axis that gets removed.
#
# axis=0 → remove rows → result per column
#
# axis=1 → remove columns → result per row
